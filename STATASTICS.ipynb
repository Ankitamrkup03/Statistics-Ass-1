# %% [markdown]
# # STATEMENT-1

# %%
import numpy
from scipy import stats
x=[6, 7, 5, 7, 7, 8, 7, 6, 9, 7, 4, 10, 6, 8, 8, 9, 5, 6, 4, 8]
y=numpy.mean(x)
print(y)

#median
z=numpy.median(x)
print(z)

#mode
s=stats.mode(x)
print(s)
# Out:
# 6.85
# 7.0
# ModeResult(mode=array([7]), count=array([5]))

# %% [markdown]
# # STATEMENT-2

# %%
import numpy
from scipy import stats
x=[28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170,100, 75, 104, 97, 75,
   123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109]
y=numpy.mean(x)
print(y)

#median
z=numpy.median(x)
print(z)

#mode
s=stats.mode(x)
print(s)
# Out:
# 107.51428571428572
# 100.0
# ModeResult(mode=array([75]), count=array([4]))

# %% [markdown]
# # STATEMENT-3

# %%
import numpy
import statistics 
from scipy import stats

x=[0.09, 0.15, 0.40, 0.25, 0.10, 0.01]
y=numpy.mean(x)
print(y)

print("Variance of sample set is % s" 
      %(statistics.variance(x)))
# Out:
# 0.16666666666666666
# Variance of sample set is 0.01930666666666667

# %% [markdown]
# # STATEMENT-5
# A company manufactures LED bulbs with a faulty rate of 30%. If I randomly select 6
# chosen LEDs, what is the probability of having 2 faulty LEDs in my sample?
# Calculate the average value of this process. Also evaluate the standard deviation
# associated with it.

# %%
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy.stats import binom


p=0.3
q=0.7      #1-0.3
n=6      #total number of trail
k=2        #number of trail successed

binomial_data=binom.rvs(n=6,p=0.3,size=1000)
sns.distplot(binomial_data,hist=True,kde=True,color="red")

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
probab=binom.pmf(k=2,n=6,p=0.3)
print("Probability will be :",probab)
cdf=binom.cdf(k=2,n=6,p=0.3)
print("CDF will be :",cdf)
# Out:
# Probability will be : 0.3241349999999999
# CDF will be : 0.74431

# %%
import scipy.stats as binom
import sys 
import math 
import numpy
mean,var=binom.stats(n=6,p=0.3)
print("mean := ',mean)
print("standard deviation :=",math.sqrt(var))
# Out:
#   File "<ipython-input-6-6a19ebd88af4>", line 6
#     print("mean := ',mean)
#                           ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # STATAMENT=7
#
# Customers arrive at a rate of 72 per hour to my shop. What is the probability of k
# customers arriving in 4 minutes? a) 5 customers, b) not more than 3 customers, c)
# more than 3 customers.

# %% [markdown]
# ![WhatsApp%20Image%202021-03-18%20at%205.50.50%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-18%20at%205.50.50%20PM.jpeg)

# %% [markdown]
# # STATEMENT=10
#
# Please compute the following:
# a) P(Z > 1.26), . P(Z < −0.86), P(Z > −1.37), P(−1.25 < Z < 0.37), . P(Z ≤ −4.6)
# b) Find the value z such that P(Z > z) = 0.05
# c) Find the value of z such that P(−z < Z < z) = 0.99

# %% [markdown]
# ![WhatsApp%20Image%202021-03-18%20at%205.48.49%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-18%20at%205.48.49%20PM.jpeg)

# %% [markdown]
# # STATEMENT=12
#
# The shaft in a piston has its diameter normally distributed with a mean of 0.2508 inch
# and a standard deviation of 0.0005 inch. The specifications of the shaft are 0.2500 ∓
# 0.0015 inch. What proportion of shafts are in sync with the specifications? If the
# process is centered so that the mean is equal to the target value of 0.2500, what
# proportion of shafts conform to the new specifications? What is your conclusion from
# this experiment?

# %% [markdown]
# ![WhatsApp%20Image%202021-03-18%20at%205.49.22%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-18%20at%205.49.22%20PM.jpeg)
